# %%
import pandas as pd

# %%
df = pd.read_csv('data/space_funding.csv')
df
# Out:
#                    Company                Type of transaction  Sector  \
# 0        Firefly Aerospace                                M&A  Launch
# 1                    Orbex  Government, Investment, Strategic  Launch
# 2                 Latitude             Government, Investment  Launch
# 3               Spinlaunch                         Investment  Launch
# 4                InnoSpace                         Investment  Launch
# ..                     ...                                ...     ...
# 163             Connectica                                NaN     NaN
# 164  Cosmic Shielding Corp                                NaN     NaN
# 165                Skyloom                                NaN     NaN
# 166                    Sen                                NaN     NaN
# 167                Adranos                                NaN     NaN
#
#                                      Lead  \
# 0                                     NaN
# ...

# %%
restricted_set = df[['Company','Type of transaction','Sector','Country','Amount USD']]

# %%
restricted_set['amount_preprocessed'] = restricted_set['Amount USD'].str.extract(r'(\d+.?\d)').astype('float')
# Out:
# C:\Users\baker\AppData\Local\Temp\ipykernel_18048\4201582997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restricted_set['amount_preprocessed'] = restricted_set['Amount USD'].str.extract(r'(\d+.?\d)').astype('float')

# %%
restricted_set['pkey'] = restricted_set.index
# Out:
# C:\Users\baker\AppData\Local\Temp\ipykernel_18048\4207534815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restricted_set['pkey'] = restricted_set.index

# %%
restricted_set.drop('Amount USD',axis=1,inplace=True)
# Out:
# C:\Users\baker\AppData\Local\Temp\ipykernel_18048\379207344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restricted_set.drop('Amount USD',axis=1,inplace=True)

# %%
restricted_set.to_csv('data/preprocessed_funding.csv')
